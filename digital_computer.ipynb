# %% [markdown]
# <a href="https://colab.research.google.com/github/Riazhatvi/Computer_Vision/blob/main/digital_computer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install matplotlib
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np

# %%
img = np.array(Image.open('/download.jpg'))
plt.figure(figsize = (4,4))
plt.imshow(img)
plt.show()

# %%
C = img

# %%
id(C) == id(img)
# Out:
# True

# %%
C = img.copy()
id(C)==id(img)
# if we apply method copy(), their memory addresses are different
# Out:
# False

# %%
img[:,:,] = 0

# %%
plt.figure(figsize=(10,10))
plt.subplot(121)
plt.imshow(img)
plt.title("Array C")
plt.subplot(122)
plt.imshow(C)
plt.title("Robot")
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.subplot(121)
plt.imshow(img)
plt.title("Robot")
plt.subplot(122)
plt.title("Array D")
plt.show()

# %%
# :Fliping Image Test

# %%
robo = Image.open("/download.jpg")
plt.figure(figsize=(4,4))
plt.imshow(robo)
plt.show()

# %%
a = np.array(robo)
width,height,C = a.shape
print('width' , width , 'height is', height, 'and Channel is ' , C)
# Out:
# width 126 height is 126 and Channel is  3

# %%
a_flip = np.zeros(height, width, C),  dtype=np.uint8
# Out:
#   File "<ipython-input-65-4802ebb0e636>", line 1
#     a_flip = np.zeros(height, width, C),  dtype=np.uint8
#     ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
for i,row in enumerate(array):
  a_flip[width -1-i,:,:] = row
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-50-fc399b67baa3> in <cell line: 1>()
# ----> 1 for i,row in enumerate(array):
#       2   a_flip[width -1-i,:,:] = row
#
# TypeError: iteration over a 0-d array

# %%
a_flip
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-64-1b19a387fe3d> in <cell line: 1>()
# ----> 1 a_flip
#
# NameError: name 'a_flip' is not defined

# %%
from PIL import ImageOps

# %%
mg_flip = ImageOps.flip(robo)
plt.figure(figsize=(10,10))
plt.imshow(mg_flip)
plt.show()

# %%
mg_mirror = ImageOps.mirror(robo)
plt.figure(figsize=(4,4))
plt.imshow(mg_mirror)
plt.show()

# %%
mg_flip = robo.transpose(1)
plt.imshow(mg_flip)
plt.show()

# %%
flp = {"FLIP_LEFT_RIGHT": Image.FLIP_LEFT_RIGHT,
        "FLIP_TOP_BOTTOM": Image.FLIP_TOP_BOTTOM,
        "ROTATE_90": Image.ROTATE_90,
        "ROTATE_180": Image.ROTATE_180,
        "ROTATE_270": Image.ROTATE_270,
        "TRANSPOSE": Image.TRANSPOSE,
        "TRANSVERSE": Image.TRANSVERSE}

# %%
flp["FLIP_TOP_BOTTOM"]
# Out:
# 1

# %%
for key, values in flp.items():
  plt.figure(figsize=(10,10))
  plt.subplot(1,2,1)
  plt.imshow(robo)
  plt.title("Original Robo")
  plt.subplot(1,2,2)
  plt.imshow(robo)
  plt.title(key)
  plt.show()

# %%
u = 50
l= 100
c_t = a[u: l,:,:]
plt.figure(figsize=(4,4))
plt.imshow(c_t)
plt.show()

# %%
le=50
r = 100
le_hr = c_t[:,le:r,:]
plt.figure(figsize=(5,5))
plt.imshow(le_hr)
plt.show()

# %%
mg1 = Image.open("/download.jpg")
c_mg1 = mg1.crop((le,u,r,l))
plt.figure(figsize=(5,5))
plt.imshow(c_mg1)
plt.show()

# %%
c_mg1 = c_mg.transpose(Image.FLIP_LEFT_RIGHT)
c_mg1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3ad5f2717825> in <cell line: 1>()
# ----> 1 c_mg1 = c_mg.transpose(Image.FLIP_LEFT_RIGHT)
#       2 c_mg1
#
# NameError: name 'c_mg' is not defined

# %%
import cv2
im2 = cv2.imread('/download.jpg')
plt.imshow(im2)
gray_im2 = cv2.cvtColor(im2,cv2.COLOR_BGR2GRAY)
plt.imshow(gray_im2)
cv2.imwrite('gray_image.jpg' , gray_im2)
edges = cv2.Canny(gray_im2,100,200)
plt.imshow(edges)
